# %%
## Processing gini wealth data

# %%
import pandas as pd

# Load your Parquet file
df = pd.read_parquet("../data/clean/euro15_gini_wealth.parquet")

# %%
df.rename(columns={"country": "country_name_german"}, inplace=True)
# Add constant year column
df["year"] = 2015
# Out:
#   Cell In[17], line 1
#     df.rename(columns={"country: "country_name_german"}, inplace=True)
#                                                      ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
df.to_parquet("../data/processed/stg_gini_wealth.parquet", index=False)

# %%
df.to_parquet("../data/core/fact_gini_wealth.parquet", index=False)
