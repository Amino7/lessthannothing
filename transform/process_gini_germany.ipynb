# %%
import pandas as pd

# %%
import os
import pandas as pd

os.makedirs("data/core", exist_ok=True)

df = pd.read_parquet("../data/processed/stg_gini.parquet")
df_sorted = df[df["country"] == "DE"].sort_values("year")

df_sorted.to_parquet("../data/core/fact_gini.parquet", index=False)
print("Saved → data/core/fact_gini.parquet")
# Out:
# Saved → data/core/fact_gini.parquet
